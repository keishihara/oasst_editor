# %%
# %load_ext autoreload
# %autoreload 2

# %%
import uuid
import pandas as pd
from datasets import load_dataset
from pandarallel import pandarallel
from pathlib import Path
from tqdm.notebook import tqdm

pandarallel.initialize(progress_bar=True, nb_workers=8)
tqdm.pandas()

DATA_DIR = Path('../data')
DATA_DIR.mkdir(exist_ok=True)
# Out:
# INFO: Pandarallel will run on 8 workers.
# INFO: Pandarallel will use standard multiprocessing data transfer (pipe) to transfer data between the main process and workers.

# %%
# load oasst2-ja
oasst2_ja = load_dataset('kunishou/oasst2-135k-ja')
df_ja = oasst2_ja['train'].to_pandas()
df_ja = df_ja.drop_duplicates(subset='message_id')
df_ja.head(1)
# Out:
#        role use_deepl index                       message_tree_id parent_id  \
# 0  prompter         1     0  002c4715-b026-48d1-8d19-3f724a9fc1e8       nan
#
#                                                 text lang  \
# 0  Dame los pasos de las cosas que debería de apr...   es
#
#                              message_id                           text_ja
# 0  002c4715-b026-48d1-8d19-3f724a9fc1e8  ゲーム開発者になるために学ぶべきことのステップを教えてください。

# %%
# load original oasst2
print('Loading oasst2..')
oasst2 = load_dataset('OpenAssistant/oasst2', split='train+validation')
df = oasst2.to_pandas()


# Merge text_ja into original oasst2 df
print('Merging..')
df = df.merge(df_ja[['message_id', 'text_ja']])
# Out:
# Loading oasst2..
# Merging..

# %%
df.shape, df_ja.shape
# Out:
# ((135174, 19), (135174, 9))

# %%
# Pre-filtering

# English and Japanese only, reviewed multiple times, and drop entries without labels
df = df.query(r'lang in ["en", "ja"] & review_count > 1 & labels.notna()')

# %%
df_filtered = df.copy()

# Converting labels
df_filtered.labels = df_filtered.labels.parallel_apply(lambda x: pd.DataFrame(x).set_index('name').transpose().to_dict())


# df_filtered.labels.str['lang_mismatch'].str['value'].plot.hist(bins=100) # == 0.0
# df_filtered.labels.str['spam'].str['value'].plot.hist(bins=100) # == 0.0
# df_filtered.labels.str['fails_task'].str['value'].plot.hist(bins=100) # == 0.0
# df_filtered.labels.str['pii'].str['value'].plot.hist(bins=100) # == 0.0  # personally identifiable information
# df_filtered.labels.str['not_appropriate'].str['value'].plot.hist(bins=100) # == 0.0
# df_filtered.labels.str['hate_speech'].str['value'].plot.hist(bins=100) # == 0.0
# df_filtered.labels.str['sexual_content'].str['value'].plot.hist(bins=100) # no rules
# df_filtered.labels.str['quality'].str['value'].plot.hist(bins=100) # >= 0.7
# df_filtered.labels.str['toxicity'].str['value'].plot.hist(bins=100) # < 0.1
# df_filtered.labels.str['humor'].str['value'].plot.hist(bins=100) # no rules
# df_filtered.labels.str['helpfulness'].str['value'].plot.hist(bins=100) # >= 0.7
# df_filtered.labels.str['creativity'].str['value'].plot.hist(bins=100) # no rules?
# df_filtered.labels.str['violence'].str['value'].plot.hist(bins=100) # == 0.0
# Out:
# VBox(children=(HBox(children=(IntProgress(value=0, description='0.00%', max=8029), Label(value='0 / 8029'))), …

# %%
df_filtered.labels.head(10).apply(lambda x: {k: v['value'] for k,v in x.items()}).apply(pd.Series).style.bar()
# Out:
# /Users/keishi.ishihara/keishi.ishihara/workspace/japanese_datasets/env/lib/python3.12/site-packages/pandas/io/formats/style.py:4040: RuntimeWarning: invalid value encountered in scalar divide
#   end = (x - left) / (right - left)
# <style type="text/css">
# #T_3fb67_row0_col0, #T_3fb67_row0_col2, #T_3fb67_row0_col3, #T_3fb67_row0_col4, #T_3fb67_row0_col5, #T_3fb67_row0_col7, #T_3fb67_row0_col8, #T_3fb67_row0_col10, #T_3fb67_row0_col11, #T_3fb67_row0_col12, #T_3fb67_row1_col0, #T_3fb67_row1_col1, #T_3fb67_row1_col2, #T_3fb67_row1_col3, #T_3fb67_row1_col4, #T_3fb67_row1_col5, #T_3fb67_row1_col8, #T_3fb67_row1_col9, #T_3fb67_row1_col10, #T_3fb67_row1_col11, #T_3fb67_row2_col0, #T_3fb67_row2_col1, #T_3fb67_row2_col2, #T_3fb67_row2_col3, #T_3fb67_row2_col4, #T_3fb67_row2_col5, #T_3fb67_row2_col7, #T_3fb67_row2_col8, #T_3fb67_row2_col9, #T_3fb67_row2_col10, #T_3fb67_row2_col11, #T_3fb67_row2_col12, #T_3fb67_row3_col0, #T_3fb67_row3_col1, #T_3fb67_row3_col2, #T_3fb67_row3_col3, #T_3fb67_row3_col4, #T_3fb67_row3_col5, #T_3fb67_row3_col10, #T_3fb67_row3_col11, #T_3fb67_row4_col0, #T_3fb67_row4_col1, #T_3fb67_row4_col2, #T_3fb67_row4_col3, #T_3fb67_row4_col4, #T_3fb67_row4_col5, #T_3fb67_row4_col7, #T_3fb67_row4_col11, #T_3fb67_row5_col0, #T_3fb67_row5_col1, #T_3fb67_row5_col2, #T_3fb67_row5_col3, #T_3fb67_row5_col4, #T_3fb67_row5_col5, #T_3fb67_row5_col7, #T_3fb67_row5_col8, #T_3fb67_row5_col10, #T_3fb67_row5_col11, #T_3fb67_row6_col0, #T_3fb67_row6_col1, #T_3fb67_row6_col2, #T_3fb67_row6_col3, #T_3fb67_row6_col4, #T_3fb67_row6_col5, #T_3fb67_row6_col8, #T_3fb67_row6_col10, #T_3fb67_row6_col11, #T_3fb67_row6_col12, #T_3fb67_row7_col0, #T_3fb67_row7_col1, #T_3fb67_row7_col2, #T_3fb67_row7_col3, #T_3fb67_row7_col4, #T_3fb67_row7_col5, #T_3fb67_row7_col10, #T_3fb67_row8_col0, #T_3fb67_row8_col1, #T_3fb67_row8_col2, #T_3fb67_row8_col3, #T_3fb67_row8_col4, #T_3fb67_row8_col5, #T_3fb67_row8_col7, #T_3fb67_row8_col8, #T_3fb67_row8_col9, #T_3fb67_row8_col10, #T_3fb67_row8_col11, #T_3fb67_row8_col12, #T_3fb67_row9_col1, #T_3fb67_row9_col2, #T_3fb67_row9_col3, #T_3fb67_row9_col4, #T_3fb67_row9_col5, #T_3fb67_row9_col7, #T_3fb67_row9_col10, #T_3fb67_row9_col11 {
#   width: 10em;
# }
# #T_3fb67_row0_col1, #T_3fb67_row3_col7, #T_3fb67_row4_col6, #T_3fb67_row4_col9, #T_3fb67_row4_col10, #T_3fb67_row4_col12, #T_3fb67_row5_col6, #T_3fb67_row6_col9, #T_3fb67_row7_col11, #T_3fb67_row9_col0, #T_3fb67_row9_col8 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 100.0%, transparent 100.0%);
# }
# #T_3fb67_row0_col6, #T_3fb67_row3_col6 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 72.7%, transparent 72.7%);
# }
# #T_3fb67_row0_col9, #T_3fb67_row7_col9 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 33.3%, transparent 33.3%);
# }
# #T_3fb67_row1_col6, #T_3fb67_row6_col6, #T_3fb67_row9_col6 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 90.9%, transparent 90.9%);
# }
# #T_3fb67_row1_col7, #T_3fb67_row6_col7, #T_3fb67_row9_col9 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 75.0%, transparent 75.0%);
# }
# #T_3fb67_row1_col12, #T_3fb67_row3_col12, #T_3fb67_row8_col6 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 81.8%, transparent 81.8%);
# }
# #T_3fb67_row2_col6 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 45.5%, transparent 45.5%);
# }
# #T_3fb67_row3_col8, #T_3fb67_row4_col8 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 22.2%, transparent 22.2%);
# }
# #T_3fb67_row3_col9 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 16.7%, transparent 16.7%);
# }
# #T_3fb67_row5_col9, #T_3fb67_row7_col7 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 50.0%, transparent 50.0%);
# }
# #T_3fb67_row5_col12, #T_3fb67_row9_col12 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 95.5%, transparent 95.5%);
# }
# #T_3fb67_row7_col6, #T_3fb67_row7_col12 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 27.3%, transparent 27.3%);
# }
# #T_3fb67_row7_col8 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 88.9%, transparent 88.9%);
# }
# </style>
# <table id="T_3fb67">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_3fb67_level0_col0" class="col_heading level0 col0" >spam</th>
#       <th id="T_3fb67_level0_col1" class="col_heading level0 col1" >lang_mismatch</th>
#       <th id="T_3fb67_level0_col2" class="col_heading level0 col2" >pii</th>
#       <th id="T_3fb67_level0_col3" class="col_heading level0 col3" >not_appropriate</th>
#       <th id="T_3fb67_level0_col4" class="col_heading level0 col4" >hate_speech</th>
#       <th id="T_3fb67_level0_col5" class="col_heading level0 col5" >sexual_content</th>
#       <th id="T_3fb67_level0_col6" class="col_heading level0 col6" >quality</th>
#       <th id="T_3fb67_level0_col7" class="col_heading level0 col7" >toxicity</th>
#       <th id="T_3fb67_level0_col8" class="col_heading level0 col8" >humor</th>
#       <th id="T_3fb67_level0_col9" class="col_heading level0 col9" >creativity</th>
#       <th id="T_3fb67_level0_col10" class="col_heading level0 col10" >violence</th>
#       <th id="T_3fb67_level0_col11" class="col_heading level0 col11" >fails_task</th>
#       <th id="T_3fb67_level0_col12" class="col_heading level0 col12" >helpfulness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_3fb67_level0_row0" class="row_heading level0 row0" >37</th>
#       <td id="T_3fb67_row0_col0" class="data row0 col0" >0.000000</td>
#       <td id="T_3fb67_row0_col1" class="data row0 col1" >0.333333</td>
#       <td id="T_3fb67_row0_col2" class="data row0 col2" >0.000000</td>
#       <td id="T_3fb67_row0_col3" class="data row0 col3" >0.000000</td>
#       <td id="T_3fb67_row0_col4" class="data row0 col4" >0.000000</td>
#       <td id="T_3fb67_row0_col5" class="data row0 col5" >0.000000</td>
#       <td id="T_3fb67_row0_col6" class="data row0 col6" >0.666667</td>
#       <td id="T_3fb67_row0_col7" class="data row0 col7" >0.000000</td>
#       <td id="T_3fb67_row0_col8" class="data row0 col8" >0.000000</td>
#       <td id="T_3fb67_row0_col9" class="data row0 col9" >0.166667</td>
#       <td id="T_3fb67_row0_col10" class="data row0 col10" >0.000000</td>
#       <td id="T_3fb67_row0_col11" class="data row0 col11" >nan</td>
#       <td id="T_3fb67_row0_col12" class="data row0 col12" >nan</td>
#     </tr>
#     <tr>
#       <th id="T_3fb67_level0_row1" class="row_heading level0 row1" >38</th>
#       <td id="T_3fb67_row1_col0" class="data row1 col0" >0.000000</td>
#       <td id="T_3fb67_row1_col1" class="data row1 col1" >0.000000</td>
#       <td id="T_3fb67_row1_col2" class="data row1 col2" >0.000000</td>
#       <td id="T_3fb67_row1_col3" class="data row1 col3" >0.000000</td>
#       <td id="T_3fb67_row1_col4" class="data row1 col4" >0.000000</td>
#       <td id="T_3fb67_row1_col5" class="data row1 col5" >0.000000</td>
#       <td id="T_3fb67_row1_col6" class="data row1 col6" >0.833333</td>
#       <td id="T_3fb67_row1_col7" class="data row1 col7" >0.125000</td>
#       <td id="T_3fb67_row1_col8" class="data row1 col8" >0.000000</td>
#       <td id="T_3fb67_row1_col9" class="data row1 col9" >0.000000</td>
#       <td id="T_3fb67_row1_col10" class="data row1 col10" >0.000000</td>
#       <td id="T_3fb67_row1_col11" class="data row1 col11" >0.000000</td>
#       <td id="T_3fb67_row1_col12" class="data row1 col12" >0.750000</td>
#     </tr>
#     <tr>
#       <th id="T_3fb67_level0_row2" class="row_heading level0 row2" >39</th>
#       <td id="T_3fb67_row2_col0" class="data row2 col0" >0.000000</td>
#       <td id="T_3fb67_row2_col1" class="data row2 col1" >0.000000</td>
#       <td id="T_3fb67_row2_col2" class="data row2 col2" >0.000000</td>
#       <td id="T_3fb67_row2_col3" class="data row2 col3" >0.000000</td>
#       <td id="T_3fb67_row2_col4" class="data row2 col4" >0.000000</td>
#       <td id="T_3fb67_row2_col5" class="data row2 col5" >0.000000</td>
#       <td id="T_3fb67_row2_col6" class="data row2 col6" >0.416667</td>
#       <td id="T_3fb67_row2_col7" class="data row2 col7" >0.000000</td>
#       <td id="T_3fb67_row2_col8" class="data row2 col8" >0.000000</td>
#       <td id="T_3fb67_row2_col9" class="data row2 col9" >0.000000</td>
#       <td id="T_3fb67_row2_col10" class="data row2 col10" >0.000000</td>
#       <td id="T_3fb67_row2_col11" class

# %%
conditions = [
    ('lang_mismatch', '==0.0'),
    ('spam', '==0.0'),
    ('fails_task', '==0.0'),
    ('pii', '==0.0'),
    ('not_appropriate', '==0.0'),
    ('hate_speech', '==0.0'),
    # ('sexual_content', ''),
    ('quality', '>=0.7'),
    ('toxicity', '<0.1'),
    # ('humor', ''),
    ('helpfulness', '>=0.7'),
    # ('creativity', ''),
    ('violence', '==0.0'),
]

conds = [f'labels.str["{k}"].str["value"]{v}' for k, v in conditions]
df_filtered = df_filtered.query(' & '.join(conds))
print(df_filtered.shape)
# Out:
# (7551, 19)

# %%
df_filtered.shape
# Out:
# (7551, 19)

# %%
import copy
import os
from collections import defaultdict
from pathlib import Path
from tqdm import tqdm
from typing import Callable, Dict, List, Literal, Union
from typing_extensions import TypeAlias

import pandas as pd
from datasets import (
    Dataset,
    load_dataset,
)
Thread: TypeAlias = List[Dict[str, str]]
Split: TypeAlias = Literal['train', 'eval', 'test', 'full']


def to_threads(df: pd.DataFrame) -> pd.DataFrame:
    nodes = defaultdict(list)
    progbar = tqdm(
        df.to_dict(orient='records'),
        dynamic_ncols=True,
        desc='Building conversation tree..'
    )
    for data in progbar:
        if data['parent_id']:
            nodes[data['parent_id']].append(data['message_id'])

    print('Converting df to dict..')
    data_dict = df.set_index('message_id').transpose().to_dict()

    def follow(thread: Thread, current_id: str) -> List[Thread]:
        # Given a thread and a current_id, return the thread that follows the current_id
        thread = thread + [{
            'message_id': current_id,
            **data_dict[current_id],
        }]

        if current_id in nodes:
            new_thread = []
            for child_id in nodes[current_id]:
                new_thread += follow(thread, child_id)
            return new_thread
        else:
            return [thread]

    def get_threads_from_root(root_id: str) -> List[Thread]:
        # Given a root_id, return all the threads in the tree
        all_threads = []
        thread = [{
            'message_id': root_id,
            **data_dict[root_id],
        }]
        for child_id in nodes[root_id]:
            all_threads += follow(thread, child_id)
        return all_threads

    df_filtered = df.copy()
    df_filtered = df[df.lang.isin(['en', 'ja'])]
    df_filtered = df_filtered[df_filtered.parent_id.isna()]


    tqdm.pandas(desc='Gathering threads..', dynamic_ncols=True, disable=False)
    ser_thread = df_filtered.message_id.progress_apply(get_threads_from_root)
    ser_thread = ser_thread.explode().reset_index(drop=True)


    # def cut_last_prompter_message(thread):
    #     if thread[-1]['role'] == 'prompter':
    #         return thread[:-1]
    #     return thread
    # tqdm.pandas(desc='Cutting last prompter message..', dynamic_ncols=True, disable=False)
    # ser_thread = ser_thread.progress_apply(cut_last_prompter_message)

    df_thread = ser_thread.to_frame(name='thread')
    df_thread['thread_id'] = df_thread.thread.apply(lambda x: str(uuid.uuid4()))

    df_thread['_full_message_id'] = df_thread.thread.apply(lambda xs: [x['message_id'] for x in xs]).str.join('_')
    df_thread = df_thread.sort_values(by='_full_message_id').reset_index(drop=True)
    df_thread = df_thread.drop(columns='_full_message_id')

    return df_thread

df_thread = to_threads(df)
# Out:
# Building conversation tree..: 100%|██████████| 64232/64232 [00:00<00:00, 2862485.36it/s]
# Converting df to dict..
# Gathering threads..: 100%|██████████| 5486/5486 [00:00<00:00, 27790.97it/s]

# %%
df_thread.thread.str[0].str['message_id'].head(10).tolist()
# Out:
# ['001199c7-7135-4e64-bee9-48ea862243b4',
#  '001199c7-7135-4e64-bee9-48ea862243b4',
#  '001199c7-7135-4e64-bee9-48ea862243b4',
#  '001199c7-7135-4e64-bee9-48ea862243b4',
#  '001199c7-7135-4e64-bee9-48ea862243b4',
#  '001199c7-7135-4e64-bee9-48ea862243b4',
#  '001199c7-7135-4e64-bee9-48ea862243b4',
#  '001199c7-7135-4e64-bee9-48ea862243b4',
#  '001199c7-7135-4e64-bee9-48ea862243b4',
#  '001199c7-7135-4e64-bee9-48ea862243b4']

# %%
# df_thread.full_message_id.sort_values().head(20).tolist()

['001199c7-7135-4e64-bee9-48ea862243b4_27376dd3-3d2e-42ae-8d17-d05265e4c587_170aa60d-d2f0-4c78-943a-2d6b49f8bd66',
 '001199c7-7135-4e64-bee9-48ea862243b4_27376dd3-3d2e-42ae-8d17-d05265e4c587_36b0d881-4008-4088-b405-b5ad43b66717',
 '001199c7-7135-4e64-bee9-48ea862243b4_27376dd3-3d2e-42ae-8d17-d05265e4c587_b6a71f0b-6703-4c33-9f9d-637003337505',
 '001199c7-7135-4e64-bee9-48ea862243b4_27376dd3-3d2e-42ae-8d17-d05265e4c587_d0cd3c86-178f-4704-aa41-eeeef5c62165',
 '001199c7-7135-4e64-bee9-48ea862243b4_27376dd3-3d2e-42ae-8d17-d05265e4c587_da6e7b94-edee-446c-940e-0080f8e6127a',
 '001199c7-7135-4e64-bee9-48ea862243b4_314ea243-638d-48d6-9f3d-8edf80f85ec2',
 '001199c7-7135-4e64-bee9-48ea862243b4_e97d0ddc-c4a5-49ce-a22f-ba3191d2fdbc_0cc74b00-7d81-47ee-8f40-3ed2a60e0d70',
 '001199c7-7135-4e64-bee9-48ea862243b4_f5eea094-f084-4375-9d64-ec3b5064203c_296a9bc7-32c3-46ad-b6ee-7d73bce89b77',
 '001199c7-7135-4e64-bee9-48ea862243b4_f5eea094-f084-4375-9d64-ec3b5064203c_49f1e48f-198e-47f0-9827-142af272e0a3',
 '001199c7-7135-4e64-bee9-48ea862243b4_f5eea094-f084-4375-9d64-ec3b5064203c_9f833ebd-6008-421b-a681-1a5c7eb0fb49',
 '001199c7-7135-4e64-bee9-48ea862243b4_f5eea094-f084-4375-9d64-ec3b5064203c_c8a40618-74da-40a2-8613-186302072e3a',
 '001199c7-7135-4e64-bee9-48ea862243b4_f5eea094-f084-4375-9d64-ec3b5064203c_cbaa4c9c-8c52-4504-bac1-17b7e3b3c9b9',
 '001199c7-7135-4e64-bee9-48ea862243b4_f5eea094-f084-4375-9d64-ec3b5064203c_d5e47805-c7cb-490d-8307-237ff227647c',
 '00258783-e10f-4d90-a3a4-abd22ea903f8_1f80b948-1d7d-4ac6-940e-e839a66f2683',
 '00258783-e10f-4d90-a3a4-abd22ea903f8_3b0cf16a-207a-4e89-9784-b0fdf061bb53',
 '00258783-e10f-4d90-a3a4-abd22ea903f8_970636b9-cbb0-4b93-af19-1d4673de9094',
 '00281075-2a0b-4543-97ed-22d345e021b2_3bb852ed-2e30-4794-95b2-cf315ead588b_2a7e7646-e512-48e9-a63b-7b596b79b424',
 '00281075-2a0b-4543-97ed-22d345e021b2_8f629231-a920-4739-acea-5a1c3e7697fc_1d82bce4-2840-4100-a200-910f5ec7b902_03a92be5-ec7a-4d59-8018-3286660f593a',
 '00281075-2a0b-4543-97ed-22d345e021b2_8f629231-a920-4739-acea-5a1c3e7697fc_1d82bce4-2840-4100-a200-910f5ec7b902_0ecf54f6-6c12-4ddb-841f-93d512d8e78a',
 '00281075-2a0b-4543-97ed-22d345e021b2_8f629231-a920-4739-acea-5a1c3e7697fc_1d82bce4-2840-4100-a200-910f5ec7b902_957e5a0e-1153-4b2e-8d1d-8a517b75c561_0e9804b2-3ffb-46fe-824c-20e281315c7a']
# Out:
# ['001199c7-7135-4e64-bee9-48ea862243b4_27376dd3-3d2e-42ae-8d17-d05265e4c587_170aa60d-d2f0-4c78-943a-2d6b49f8bd66',
#  '001199c7-7135-4e64-bee9-48ea862243b4_27376dd3-3d2e-42ae-8d17-d05265e4c587_36b0d881-4008-4088-b405-b5ad43b66717',
#  '001199c7-7135-4e64-bee9-48ea862243b4_27376dd3-3d2e-42ae-8d17-d05265e4c587_b6a71f0b-6703-4c33-9f9d-637003337505',
#  '001199c7-7135-4e64-bee9-48ea862243b4_27376dd3-3d2e-42ae-8d17-d05265e4c587_d0cd3c86-178f-4704-aa41-eeeef5c62165',
#  '001199c7-7135-4e64-bee9-48ea862243b4_27376dd3-3d2e-42ae-8d17-d05265e4c587_da6e7b94-edee-446c-940e-0080f8e6127a',
#  '001199c7-7135-4e64-bee9-48ea862243b4_314ea243-638d-48d6-9f3d-8edf80f85ec2',
#  '001199c7-7135-4e64-bee9-48ea862243b4_e97d0ddc-c4a5-49ce-a22f-ba3191d2fdbc_0cc74b00-7d81-47ee-8f40-3ed2a60e0d70',
#  '001199c7-7135-4e64-bee9-48ea862243b4_f5eea094-f084-4375-9d64-ec3b5064203c_296a9bc7-32c3-46ad-b6ee-7d73bce89b77',
#  '001199c7-7135-4e64-bee9-48ea862243b4_f5eea094-f084-4375-9d64-ec3b5064203c_49f1e48f-198e-47f0-9827-142af272e0a3',
#  '001199c7-7135-4e64-bee9-48ea862243b4_f5eea094-f084-4375-9d64-ec3b5064203c_9f833ebd-6008-421b-a681-1a5c7eb0fb49',
#  '001199c7-7135-4e64-bee9-48ea862243b4_f5eea094-f084-4375-9d64-ec3b5064203c_c8a40618-74da-40a2-8613-186302072e3a',
#  '001199c7-7135-4e64-bee9-48ea862243b4_f5eea094-f084-4375-9d64-ec3b5064203c_cbaa4c9c-8c52-4504-bac1-17b7e3b3c9b9',
#  '001199c7-7135-4e64-bee9-48ea862243b4_f5eea094-f084-4375-9d64-ec3b5064203c_d5e47805-c7cb-490d-8307-237ff227647c',
#  '00258783-e10f-4d90-a3a4-abd22ea903f8_1f80b948-1d7d-4ac6-940e-e839a66f2683',
#  '00258783-e10f-4d90-a3a4-abd22ea903f8_3b0cf16a-207a-4e89-9784-b0fdf061bb53',
#  '00258783-e10f-4d90-a3a4-abd22ea903f8_970636b9-cbb0-4b93-af19-1d4673de9094',
#  '00281075-2a0b-4543-97ed-22d345e021b2_3bb852ed-2e30-4794-95b2-cf315ead588b_2a7e7646-e512-48e9-a63b-7b596b79b424',
#  '00281075-2a0b-4543-97ed-22d345e021b2_8f629231-a920-4739-acea-5a1c3e7697fc_1d82bce4-2840-4100-a200-910f5ec7b902_03a92be5-ec7a-4d59-8018-3286660f593a',
#  '00281075-2a0b-4543-97ed-22d345e021b2_8f629231-a920-4739-acea-5a1c3e7697fc_1d82bce4-2840-4100-a200-910f5ec7b902_0ecf54f6-6c12-4ddb-841f-93d512d8e78a',
#  '00281075-2a0b-4543-97ed-22d345e021b2_8f629231-a920-4739-acea-5a1c3e7697fc_1d82bce4-2840-4100-a200-910f5ec7b902_957e5a0e-1153-4b2e-8d1d-8a517b75c561_0e9804b2-3ffb-46fe-824c-20e281315c7a']

# %%
df_thread.thread_id.nunique()
# Out:
# 32329

# %%
exploded = df_thread.explode(column='thread')
exploded['accepted'] = exploded.thread.str['message_id'].isin(df_filtered.message_id)

def add_accepted_key(row):
    thread = row.thread
    thread['accepted'] = row.accepted
    return thread
exploded.thread = exploded.apply(add_accepted_key, axis=1)
exploded = exploded.drop(columns='accepted')

agged = exploded.groupby(by='thread_id').agg({'thread': lambda x: x.tolist()})
agged = agged.reset_index()

# %%
# 全てのメッセージがacceptedになるthreadはない...
assert agged.thread.apply(lambda xs: all(x['accepted'] for x in xs)).sum() == 0


# 全てのレスポンスがacceptedになるthreadはあるか? 一応あるが少ない(1割未満)
import numpy as np
def are_all_assistants_accepted(row):
    is_assistant = [msg['role'] == 'assistant' for msg in row.thread]
    indices = np.where(is_assistant)[0].tolist()
    return all(np.array([msg['accepted'] for msg in row.thread])[indices])
display(agged.apply(are_all_assistants_accepted, axis=1).value_counts() / len(agged))


# 全てのレスポンスがaccepted、もしくはthread長が5以上の場合は採用(マルチターンのやり取りを積極的に採用したいので)
curated = agged[
    agged.apply(are_all_assistants_accepted, axis=1)
    | (agged.thread.str.len().ge(5))
].copy()
curated = curated.reset_index(drop=True)
# Out:
# False    0.915401
# True     0.084599
# Name: count, dtype: float64

# %%
curated.thread.str.len().value_counts()
# Out:
# thread
# 5    3222
# 6    1133
# 3    1017
# 2     814
# 4     731
# 7       1
# Name: count, dtype: int64

# %%
curated['message_tree_id'] = curated.thread.str[0].str['message_tree_id']
curated
# Out:
#                                  thread_id  \
# 0     00089988-1a2c-4f7c-8587-7af3fb910a48
# 1     0025519f-5409-403e-b6d1-0f3fff58ede7
# 2     0038730f-88fb-4c26-b1e2-0de999fbb98a
# 3     0039d3de-06db-41fe-b6c4-1ac28804c593
# 4     003c52d8-814c-45d6-8b88-1230681c7774
# ...                                    ...
# 6913  ffdcabca-15ef-49e6-80a0-ed5a62d97400
# 6914  ffde1edd-e3dc-4860-bf01-4b47d9bbe739
# 6915  ffe02059-eb0e-4481-86b0-a0a3564e5c3a
# 6916  ffe2fa7c-969e-4278-9549-a5228be33efa
# 6917  ffe32a09-5b7e-44d4-9de1-a97ed0724be1
#
#                                                  thread  \
# 0     [{'message_id': '446fc6e7-e89e-4180-8174-7b905...
# 1     [{'message_id': 'ba5a201c-0002-4929-b150-17287...
# 2     [{'message_id': '7b6b5187-129d-4080-99b9-c3096...
# 3     [{'message_id': 'c55433f8-6bf6-45ab-aed8-e3634...
# 4     [{'message_id': 'fa784fb9-ad4b-4a11-96c4-f33e8...
# ...                                                 ...
# 6913  [{'message_id': '7c9596ad-5f03-4882-83ce-92445...
# 6914  [{'message_id': '18e1fe57-7822-4913-b8d3-d5141...
# 6915  [{'message_id': '446fc6e7-e89e-4180-8174-7b905...
# 6916  [{'message_id': 'c3e80548-8c83-4f0f-9999-32920...
# 6917  [{'message_id': '5c6a0593-e4ab-41e8-a23d-82442...
#
#                            message_tree_id
# 0     446fc6e7-e89e-4180-8174-7b905a57fa6f
# 1     ba5a201c-0002-4929-b150-17287bfee059
# 2     7b6b5187-129d-4080-99b9-c3096dd3ef52
# 3     c55433f8-6bf6-45ab-aed8-e36340fb233b
# 4     fa784fb9-ad4b-4a11-96c4-f33e8132bf7d
# ...                                    ...
# 6913  7c9596ad-5f03-4882-83ce-92445b5ffe4a
# 6914  18e1fe57-7822-4913-b8d3-d5141282c8e0
# 6915  446fc6e7-e89e-4180-8174-7b905a57fa6f
# 6916  c3e80548-8c83-4f0f-9999-329205e39fe7
# 6917  5c6a0593-e4ab-41e8-a23d-8244294fc12a
#
# [6918 rows x 3 columns]

# %%
curated.message_tree_id.nunique()
# Out:
# 3563

# %%
def extract_message_ids_from(thread):
    return [message['message_id'] for message in thread]
curated['message_ids'] = curated.thread.apply(extract_message_ids_from)
curated = curated[['thread_id', 'message_tree_id', 'message_ids', 'thread']]
curated.head(2)
# Out:
#                               thread_id                       message_tree_id  \
# 0  00089988-1a2c-4f7c-8587-7af3fb910a48  446fc6e7-e89e-4180-8174-7b905a57fa6f
# 1  0025519f-5409-403e-b6d1-0f3fff58ede7  ba5a201c-0002-4929-b150-17287bfee059
#
#                                          message_ids  \
# 0  [446fc6e7-e89e-4180-8174-7b905a57fa6f, 8fe7d1c...
# 1  [ba5a201c-0002-4929-b150-17287bfee059, 4895d26...
#
#                                               thread
# 0  [{'message_id': '446fc6e7-e89e-4180-8174-7b905...
# 1  [{'message_id': 'ba5a201c-0002-4929-b150-17287...

# %%
def assert_all_tree_id_match(thread) -> bool:
    return len(set([msg['message_tree_id'] for msg in thread])) == 1
curated.thread.apply(assert_all_tree_id_match).sum()
# Out:
# 6918

# %%
curated.drop(columns='thread').to_json(DATA_DIR / 'curated_data_id.jsonl', orient='records', lines=True, force_ascii=False)

# %%
df_ = pd.read_json(DATA_DIR / 'curated_data_id.jsonl', lines=True)
df_['_full_message_id'] = df_.message_ids.str.join('_')
df_.sort_values(by='_full_message_id').reset_index(drop=True).drop(columns='_full_message_id')
# Out:
#                                  thread_id  \
# 0     984778c4-85fe-4015-b2ec-ca8ab31a8f54
# 1     56c73584-11ad-4371-8577-8b71b8fd84e9
# 2     71d21406-3f39-42e5-92c4-4cd2ef5ff2aa
# 3     1cd50dc3-7b7a-4cc3-879c-d8790016fe6d
# 4     f55efc35-d582-4ff9-ade1-3299f54fd7b4
# ...                                    ...
# 6913  0c0edaad-4377-4810-8b9c-b63975e735bd
# 6914  de0f2913-dcba-4742-888b-1ddf01d83a43
# 6915  8a972935-2631-4413-9715-90b3e556970d
# 6916  04823f85-e34a-42f7-8085-d1597098aed2
# 6917  2fc8ce31-623f-4b86-9a80-c101911478a4
#
#                            message_tree_id  \
# 0     001199c7-7135-4e64-bee9-48ea862243b4
# 1     00258783-e10f-4d90-a3a4-abd22ea903f8
# 2     00258783-e10f-4d90-a3a4-abd22ea903f8
# 3     00281075-2a0b-4543-97ed-22d345e021b2
# 4     00281075-2a0b-4543-97ed-22d345e021b2
# ...                                    ...
# 6913  fff90ee9-d91a-42d3-8a05-ce3cd68109e9
# 6914  fffce5e2-528c-45ea-a332-9cffdaff4326
# 6915  fffce5e2-528c-45ea-a332-9cffdaff4326
# 6916  fffce5e2-528c-45ea-a332-9cffdaff4326
# 6917  fffce5e2-528c-45ea-a332-9cffdaff4326
#
#                                             message_ids
# 0     [001199c7-7135-4e64-bee9-48ea862243b4, 314ea24...
# 1     [00258783-e10f-4d90-a3a4-abd22ea903f8, 1f80b94...
# 2     [00258783-e10f-4d90-a3a4-abd22ea903f8, 970636b...
# 3     [00281075-2a0b-4543-97ed-22d345e021b2, 8f62923...
# 4     [00281075-2a0b-4543-97ed-22d345e021b2, 8f62923...
# ...                                                 ...
# 6913  [fff90ee9-d91a-42d3-8a05-ce3cd68109e9, 4a29b7f...
# 6914  [fffce5e2-528c-45ea-a332-9cffdaff4326, 8afd96f...
# 6915  [fffce5e2-528c-45ea-a332-9cffdaff4326, 8afd96f...
# 6916  [fffce5e2-528c-45ea-a332-9cffdaff4326, 8afd96f...
# 6917  [fffce5e2-528c-45ea-a332-9cffdaff4326, 8afd96f...
#
# [6918 rows x 3 columns]

# %%
# Data itself and additional fields
curated_flat = curated.thread.explode().drop_duplicates().reset_index(drop=True).apply(pd.Series)

# adding supporting columns
curated_flat['ready_to_export'] = False
curated_flat['edited_time'] = None # pd.to_datetime('now', utc=True)
curated_flat['text_ja_audited'] = curated_flat.text_ja.copy()
curated_flat['quality'] = -1

# %%
# number of unique assistant responses
curated_flat[curated_flat.role == 'assistant'].message_id.nunique()
# 10470
# Out:
# 10470

# %%
def extract_sentence_ending_patterns(text):
    if not text:
        return None
    sentences = text.split('。')
    return [line[-5:] for line in sentences if line]

ending_patterns = curated_flat[curated_flat.role == 'assistant'].text_ja.apply(extract_sentence_ending_patterns).explode()
ending_patterns.value_counts().iloc[30:60].index.tolist()
# Out:
# ['ことが多い',
#  'なっている',
#  '勧めします',
#  '異なります',
#  'できません',
#  'こともある',
#  'が大切です',
#  'ください！',
#  'いでしょう',
#  '提供します',
#  'が含まれる',
#  'くなります',
#  '作成します',
#  'ことになる',
#  'のに役立つ',
#  'を提供する',
#  'などがある',
#  'べきである',
#  '供している',
#  'を意味する',
#  'を作成する',
#  'けましょう',
#  '使用します',
#  '用されます',
#  'はできない',
#  '持っている',
#  'うにします',
#  '使用される',
#  'せください',
#  'めましょう']

# %%
def replace_some_trailing_words(text):
    trailing_replacements = {
        'がある': 'があります',
        'である': 'です',
        'できる': 'できます',
        'されている': 'されています',
        'もしれない': 'もしれません',
        'られている': 'られています',
        'ことである': 'ことです',
        'ならない': 'なりません',
    }

    # replace trailing words
    for k,v in trailing_replacements.items():
        text = text.replace(f'{k}。', f'{v}。')
    return text


def preprocess_text_ja_audited(text):
    # replace trailing words
    if not text:
        return None

    text = replace_some_trailing_words(text)

    return text

curated_flat.loc[curated_flat.role == 'assistant', 'text_ja_audited'] = curated_flat.loc[curated_flat.role == 'assistant', 'text_ja_audited'].apply(preprocess_text_ja_audited)

# %%
curated_flat.head(2)
# Out:
#                              message_id                             parent_id  \
# 0  446fc6e7-e89e-4180-8174-7b905a57fa6f                                  None
# 1  8fe7d1cd-b2b8-4430-8a0c-21262ca75b3a  446fc6e7-e89e-4180-8174-7b905a57fa6f
#
#                                 user_id                      created_date  \
# 0  b0995156-eeff-42dc-81a1-720b604289ee  2023-02-06T07:35:30.863196+00:00
# 1  ffe55102-634f-4f20-aaf3-140288f993ed  2023-02-06T19:03:38.761117+00:00
#
#                          text       role lang  review_count review_result  \
# 0                       hello   prompter   en             3          True
# 1  Hello! How can I help you?  assistant   en             3          True
#
#    deleted  ...                       message_tree_id        tree_state  \
# 0    False  ...  446fc6e7-e89e-4180-8174-7b905a57fa6f  ready_for_export
# 1    False  ...  446fc6e7-e89e-4180-8174-7b905a57fa6f  ready_for_export
#
#                             emojis  \
# 0  {'name': ['-1'], 'count': [12]}
# 1   {'name': ['+1'], 'count': [3]}
#
#                                               labels          text_ja  \
# 0  {'name': ['spam', 'lang_mismatch', 'pii', 'not...            こんにちわ
# 1  {'name': ['spam', 'fails_task', 'lang_mismatch...  こんにちは、どうされましたか？
#
#   accepted ready_to_export edited_time  text_ja_audited  quality
# 0    False           False        None            こんにちわ       -1
# 1    False           False        None  こんにちは、どうされましたか？       -1
#
# [2 rows x 24 columns]

# %%
# Save to jsonl
curated_flat.to_json(DATA_DIR / 'curated_data_flat.jsonl', orient='records', lines=True, force_ascii=False)

# %%
df = pd.read_json(DATA_DIR / 'curated_data_flat.jsonl', lines=True)
df = df.sort_values(by='message_id').reset_index(drop=True)
df
# Out:
#                                  message_id  \
# 0      000017fc-c25f-41e5-ac44-126f0535b637
# 1      0000de03-57d2-41f5-a1c1-d2dfb9a22d0e
# 2      00073f95-cc06-40ed-af40-0e9a77981bba
# 3      000da49c-db61-49cb-bb49-64fa973a4d00
# 4      000e29df-4cb1-4b50-b5cc-7c7828046453
# ...                                     ...
# 22057  fff8d81e-3d50-4c69-8f96-4db95ebe4a96
# 22058  fff90ee9-d91a-42d3-8a05-ce3cd68109e9
# 22059  fffa0a5e-c78a-4c92-9948-34ff9de508d9
# 22060  fffce5e2-528c-45ea-a332-9cffdaff4326
# 22061  fffe7c6d-4b6a-437c-89ff-0c85fd1670fc
#
#                                   parent_id  \
# 0      304d68e8-0ba8-4917-af36-6691dcb24b83
# 1      19ce3b23-a0b7-4fd0-bd81-dabf79314654
# 2      02d93f78-0438-4ee6-a867-241266c65bc9
# 3      09110b16-a809-48ed-8309-33224ad16e97
# 4      11a38955-2b18-40e7-8df0-82a7f4798d63
# ...                                     ...
# 22057  0e4887c1-76cb-4a1c-a10e-79be271be82a
# 22058                                  None
# 22059  0cdf86d8-ead1-4442-84a6-94837461f772
# 22060                                  None
# 22061  9b399fbd-27e6-4c3e-8e0a-cef3df38af16
#
#                                     user_id                      created_date  \
# 0      a5c1f15d-b073-4668-9110-e7089c80a527  2023-04-07T08:24:09.839800+00:00
# 1      d4694407-daf2-4d56-8d8c-ecf3179db0fc  2023-04-10T19:34:37.098837+00:00
# 2      61caac78-0855-4903-bab1-5a8e26a945c6  2023-09-15T05:28:53.549598+00:00
# 3      e0c60c52-9f4f-4e21-857e-5692f563abe3  2023-04-17T17:15:42.424008+00:00
# 4      4dbc02f9-a6bd-4d96-9bbc-4d734329a9dd  2023-04-22T15:34:50.867079+00:00
# ...                                     ...                               ...
# 22057  dd92f20e-43d3-4812-afe8-7fcf0cf7c7a0  2023-04-08T14:21:21.634448+00:00
# 22058  7b14596d-21b7-42ba-9ce3-f8b19be39d11  2023-02-11T11:40:19.906642+00:00
# 22059  18d2e4e9-ecbf-4bdf-918d-233b84cec2d4  2023-04-07T17:34:06.801565+00:00
# 22060  a41f23d1-dc75-497d-8d99-a5b7b061022f  2023-02-21T19:50:43.359360+00:00
# 22061  626fdcdd-07dd-4c59-9364-1015b2823582  2023-03-22T12:16:13.623084+00:00
#
#                                                     text       role lang  \
# 0      The observable universe consists of approximat...  assistant   en
# 1      Are there any rust libraries that help me impl...   prompter   en
# 2      Osteoarthritis is the most common type of arth...  assistant   en
# 3      Greetings, my dear friend. I understand that y...  assistant   en
# 4      I can help you solve the task you have given m...  assistant   en
# ...                                                  ...        ...  ...
# 22057  A capacitor temporarily stores electrical ener...  assistant   en
# 22058          Which languages are spoken in Costa Rica?   prompter   en
# 22059  Here are some tips to make your garden more dr...  assistant   en
# 22060  Tell me which Free and Open Source tools I can...   prompter   en
# 22061  Aphex Twin, whose real name is Richard D. Jame...  assistant   en
#
#        review_count  review_result  deleted  ...  \
# 0                 3            1.0    False  ...
# 1                 3            1.0    False  ...
# 2                 3            1.0    False  ...
# 3                 5            1.0    False  ...
# 4                 5            1.0    False  ...
# ...             ...            ...      ...  ...
# 22057             3            1.0    False  ...
# 22058             3            1.0    False  ...
# 22059             3            1.0    False  ...
# 22060             3            1.0    False  ...
# 22061             3            1.0    False  ...
#
#                             message_tree_id        tree_state  \
# 0      304d68e8-0ba8-4917-af36-6691dcb24b83  ready_for_export
# 1      ef44d9ba-0f39-4060-8035-9687f2696977  ready_for_export
# 2      c3aee9f9-69c4-446d-8e21-a24a9635b51f  ready_for_export
# 3      09110b16-a809-48ed-8309-33224ad16e97  ready_for_export
# 4      11a38955-2b18-40e7-8df0-82a7f4798d63  ready_for_export
# ...                                     ...               ...
# 22057  0e4887c1-76cb-4a1c-a10e-79be271be82a  ready_for_export
# 22058  fff90ee9-d91a-42d3-8a05-ce3cd68109e9  ready_for_export
# 22059  0cdf86d8-ead1-4442-84a6-94837461f772  ready_for_export
# 22060  fffce5e2-528c-45ea-a332-9cffdaff4326  ready_for_export
# 22061  9b399fbd-27e6-4c3e-8e0a-cef3df38af16  ready_for_export
#
#                                                   emojis  \
# 0             {'name': ['_skip_labeling'], 'count': [1]}
# 1                                                   None
# 2      {'name': ['+1', '_skip_reply', '_skip_labeling...
# 3      {'name': ['+1', '_skip_labeling'], 'count': [4...
# 4      {'name': ['+1', '-1', '_skip_reply', '_skip_la...
# ...                                                  ...
# 22057            {'name': ['_skip_reply'], 'count': [1]}
# 22058   {'name': ['+1', '_skip_reply'], 'count': [3, 1]}
# 22059  {'name': ['+1', '_skip_labeling'], 'count': [2...
# 22060  {'name': ['+1', '_skip_reply', '_skip_labeling...
# 22061         {'name': ['_skip_labeling'], 'count': [3]}
#
#                                                   labels  \
# 0      {'name': ['spam', 'fails_task', 'lang_mismatch...
# 1      {'name': ['spam', 'lang_mismatch', 'pii', 'not...
# 2      {'name': ['spam', 'fails_task', 'lang_mismatch...
# 3      {'name': ['spam', 'fails_task', 'lang_mismatch...
# 4      {'name': ['spam', 'fails_task', 'lang_mismatch...
# ...                                                  ...
# 22057  {'name': ['spam', 'fails_task', 'lang_mismatch...
# 22058  {'name': ['spam', 'lang_mismatch', 'pii', 'not...
# 22059  {'name': ['spam', 'fails_task', 'lang_mismatch...
# 22060  {'name': ['spam', 'lang_mismatch', 'pii', 'not...
# 22061  {'name': ['spam', 'fails_task', 'lang_mismatch...
#
#                                                  text_ja accepted  \
# 0      観測可能な宇宙は約1000億個の銀河で構成されている。それぞれの銀河には平均して約1兆個、1...     True
# 1                             DHTの実装に役立つRubyライブラリはありますか？    False
# 2      変形性関節症は最も一般的なタイプの関節炎で、世界中で数百万人が罹患しています。関節の軟骨が徐...     True
# 3      親愛なる友人よ、こんにちは。あなたが迷い、困難な状況に追い詰められていると感じていることは理...    False
# 4      私はあなたに与えられた課題を解決する手助けができます。\n\n4つのグラブにおけるグリップの...     True
# ...                                                  ...      ...
# 22057  コンデンサは、荷電粒子を（通常は2枚の）プレートに分散させて電位差を作り、電気エネルギーを一...     True
# 22058                              コスタリカではどの言語が話されていますか？    False
# 22059  乾燥に強い庭にするためのヒントをいくつか紹介しよう：\n\n1.植物の土に堆肥を混ぜる。こう...     True
# 22060  色が劣化し、アーチファクトや傷のある古い写真を復元するために、フリーでオープンソースのツール...    False
# 22061  エイフェックス・ツイン、本名リチャード・D・ジェームスは、長年にわたり多くの影響を受けてきた...     True
#
#       ready_to_export edited_time  \
# 0               False         NaT
# 1               False         NaT
# 2               False         NaT
# 3               False         NaT
# 4               False         NaT
# ...               ...         ...
# 22057           False         NaT
# 22058           False         NaT
# 22059           False         NaT
# 22060           False         NaT
# 22061           False         NaT
#
#                                          text_ja_audited  quality
# 0      観測可能な宇宙は約1000億個の銀河で構成されています。それぞれの銀河には平均して約1兆個、...       -1
# 1                             DHTの実装に役立つRubyライブラリはありますか？       -1
# 2      変形性関節症は最も一般的なタイプの関節炎で、世界中で数百万人が罹患しています。関節の軟骨が徐...       -1
# 3      親愛なる友人よ、こんにちは。あなたが迷い、困難な状況に追い詰められていると感じていることは理...       -1
# 4      私はあなたに与えられた課題を解決する手助けができます。\n\n4つのグラブにおけるグリップの...       -1
# ...                                                  ...      ...
# 22057  コンデンサは、荷電粒子を（通常は2枚の）プレートに分散させて電位差を作り、電気エネルギーを一...       -1
# 22058                              コスタリカではどの言語が話されていますか？       -1
# 22059  乾燥に強い庭にするためのヒントをいくつか紹介しよう：\n\n1.植物の土に堆肥を混ぜる。こう...       -1
# 22060  色が劣化し、アーチファクトや傷のある古い写真を復元するために、フリーでオープンソースのツール...       -1
# 22061  エイフェックス・ツイン、本名リチャード・D・ジェームスは、長年にわたり多くの影響を受けてきた...       -1
#
# [22062 rows x 24 columns]

# %%
curated_flat[curated_flat.role == 'assistant'].text.str.split().str.len().sum()
# Out:
# 1557739

# %%
curated_flat.head(2).set_index('message_id', drop=False).transpose()
# Out:
# message_id                    446fc6e7-e89e-4180-8174-7b905a57fa6f  \
# message_id                    446fc6e7-e89e-4180-8174-7b905a57fa6f
# parent_id                                                     None
# user_id                       b0995156-eeff-42dc-81a1-720b604289ee
# created_date                      2023-02-06T07:35:30.863196+00:00
# text                                                         hello
# role                                                      prompter
# lang                                                            en
# review_count                                                     3
# review_result                                                 True
# deleted                                                      False
# rank                                                           NaN
# synthetic                                                    False
# model_name                                                    None
# detoxify         {'toxicity': 0.0007285278989002109, 'severe_to...
# message_tree_id               446fc6e7-e89e-4180-8174-7b905a57fa6f
# tree_state                                        ready_for_export
# emojis                             {'name': ['-1'], 'count': [12]}
# labels           {'name': ['spam', 'lang_mismatch', 'pii', 'not...
# text_ja                                                      こんにちわ
# accepted                                                     False
# ready_to_export                                              False
# edited_time                                                   None
# text_ja_audited                                              こんにちわ
# quality                                                         -1
#
# message_id                    8fe7d1cd-b2b8-4430-8a0c-21262ca75b3a
# message_id                    8fe7d1cd-b2b8-4430-8a0c-21262ca75b3a
# parent_id                     446fc6e7-e89e-4180-8174-7b905a57fa6f
# user_id                       ffe55102-634f-4f20-aaf3-140288f993ed
# created_date                      2023-02-06T19:03:38.761117+00:00
# text                                    Hello! How can I help you?
# role                                                     assistant
# lang                                                            en
# review_count                                                     3
# review_result                                                 True
# deleted                                                      False
# rank                                                           1.0
# synthetic                                                    False
# model_name                                                    None
# detoxify         {'toxicity': 0.0005871785106137395, 'severe_to...
# message_tree_id               446fc6e7-e89e-4180-8174-7b905a57fa6f
# tree_state                                        ready_for_export
# emojis                              {'name': ['+1'], 'count': [3]}
# labels           {'name': ['spam', 'fails_task', 'lang_mismatch...
# text_ja                                            こんにちは、どうされましたか？
# accepted                                                     False
# ready_to_export                                              False
# edited_time                                                   None
# text_ja_audited                                    こんにちは、どうされましたか？
# quality                                                         -1

# %%
curated_flat.head(2).set_index('message_id', drop=False).transpose().to_dict()
# Out:
# {'446fc6e7-e89e-4180-8174-7b905a57fa6f': {'message_id': '446fc6e7-e89e-4180-8174-7b905a57fa6f',
#   'parent_id': None,
#   'user_id': 'b0995156-eeff-42dc-81a1-720b604289ee',
#   'created_date': '2023-02-06T07:35:30.863196+00:00',
#   'text': 'hello',
#   'role': 'prompter',
#   'lang': 'en',
#   'review_count': 3,
#   'review_result': True,
#   'deleted': False,
#   'rank': nan,
#   'synthetic': False,
#   'model_name': None,
#   'detoxify': {'toxicity': 0.0007285278989002109,
#    'severe_toxicity': 4.8065045120893046e-05,
#    'obscene': 0.00039666841621510684,
#    'identity_attack': 0.00018520453886594623,
#    'insult': 0.0005383103271014988,
#    'threat': 6.978680175961927e-05,
#    'sexual_explicit': 4.260181958670728e-05},
#   'message_tree_id': '446fc6e7-e89e-4180-8174-7b905a57fa6f',
#   'tree_state': 'ready_for_export',
#   'emojis': {'name': array(['-1'], dtype=object),
#    'count': array([12], dtype=int32)},
#   'labels': {'name': array(['spam', 'lang_mismatch', 'pii', 'not_appropriate', 'hate_speech',
#           'sexual_content', 'quality', 'toxicity', 'humor', 'creativity',
#           'violence'], dtype=object),
#    'value': array([0.33333333, 0.        , 0.        , 0.        , 0.        ,
#           0.        , 0.16666667, 0.16666667, 0.33333333, 0.        ,
#           0.        ]),
#    'count': array([3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3], dtype=int32)},
#   'text_ja': 'こんにちわ',
#   'accepted': False,
#   'ready_to_export': False,
#   'edited_time': None,
#   'text_ja_audited': 'こんにちわ',
#   'quality': -1},
#  '8fe7d1cd-b2b8-4430-8a0c-21262ca75b3a': {'message_id': '8fe7d1cd-b2b8-4430-8a0c-21262ca75b3a',
#   'parent_id': '446fc6e7-e89e-4180-8174-7b905a57fa6f',
#   'user_id': 'ffe55102-634f-4f20-aaf3-140288f993ed',
#   'created_date': '2023-02-06T19:03:38.761117+00:00',
#   'text': 'Hello! How can I help you?',
#   'role': 'assistant',
#   'lang': 'en',
#   'review_count': 3,
#   'review_result': True,
#   'deleted': False,
#   'rank': 1.0,
#   'synthetic': False,
#   'model_name': None,
#   'detoxify': {'toxicity': 0.0005871785106137395,
#    'severe_toxicity': 3.730303069460206e-05,
#    'obscene': 0.00024012880749069154,
#    'identity_attack': 0.00011041590914828703,
#    'insult': 0.0002677586453501135,
#    'threat': 5.3088187996763736e-05,
#    'sexual_explicit': 2.7603944545262493e-05},
#   'message_tree_id': '446fc6e7-e89e-4180-8174-7b905a57fa6f',
#   'tree_state': 'ready_for_export',
#   'emojis': {'name': array(['+1'], dtype=object),
#    'count': array([3], dtype=int32)},
#   'labels': {'name': array(['spam', 'fails_task', 'lang_mismatch', 'pii', 'not_appropriate',
#           'hate_speech', 'sexual_content', 'quality', 'toxicity', 'humor',
#           'helpfulness', 'creativity', 'violence'], dtype=object),
#    'value': array([0.        , 0.        , 0.        , 0.        , 0.        ,
#           0.        , 0.        , 0.66666667, 0.08333333, 0.16666667,
#           0.75      , 0.        , 0.        ]),
#    'count': array([3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3], dtype=int32)},
#   'text_ja': 'こんにちは、どうされましたか？',
#   'accepted': False,
#   'ready_to_export': False,
#   'edited_time': None,
#   'text_ja_audited': 'こんにちは、どうされましたか？',
#   'quality': -1}}
